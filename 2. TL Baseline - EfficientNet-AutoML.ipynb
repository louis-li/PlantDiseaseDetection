# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split

import tensorflow.keras as keras
from tensorflow.keras import applications
from tensorflow.keras.layers import Flatten, LeakyReLU, Dense
from tensorflow.keras.models import *
from tensorflow.keras import optimizers
from tensorflow.keras.callbacks import ReduceLROnPlateau, EarlyStopping
import random
import matplotlib.pyplot as plt
from tensorflow import keras
from tensorflow.keras import layers
import tensorflow as tf
from datetime import date

from tensorflow.keras.preprocessing.image import load_img
from tensorflow.keras.preprocessing.image import img_to_array

from os import listdir
from os.path import isfile, join

# training data
image_size = 224
labels = pd.read_csv("data/fgvc7/train.csv")
image_dir = "data/fgvc7/images"

# %%
# import image data and combine labels
def load_data(dataset='Train',image_dir= 'data/fgvc7/images'):
    X = []
    y = []
    for f in listdir(image_dir):
        if isfile(join(image_dir, f)) and f[:len(dataset)]==dataset:
            # add filename
            #train_list.append(f)
            # add image to the list
            img = load_img(f'{image_dir}/{f}', target_size=(image_size,image_size,3))
            img_array = img_to_array(img, dtype='uint8')
            # Get id
            id = int(f[len(dataset)+1:-4])
            X.append(img_array)
            if dataset=='Train':
                y.append(labels.iloc[id][['healthy', 'multiple_diseases', 'rust', 'scab']].to_numpy())
            else:
                y.append([f[:-4], id])
    if dataset=='Train':
        y = np.array(y, dtype=np.uint16)   
    return np.array(X, dtype=np.uint16), y

# %%
# import training data and combine labels
data_x, data_y  = load_data()

# %% [markdown]
# ## Augmentation

# %%
import imgaug.augmenters as iaa
seq = iaa.Sequential([
    iaa.SomeOf((0,2),[
        iaa.Identity(),
        iaa.AverageBlur(k=((3, 5), (5, 7))),
        iaa.Rotate((-45,45)),
        iaa.Affine(scale=(0.5, 0.95)),    
        iaa.Multiply((0.50, 1.1))
        #,iaa.BlendAlphaRegularGrid(nb_rows=(4, 6), nb_cols=(1, 4),
        #                        foreground=iaa.Multiply(0.0))
        #,iaa.Cartoon()
        ,iaa.Cutout(nb_iterations=(1, 3), size=0.2, squared=False, cval=0)
        ,iaa.Affine(shear=(-48, 48))
        ,iaa.Affine(translate_px={"x": (-42, 42), "y": (-36, 36)})
        ,iaa.KeepSizeByResize(iaa.Resize({"height": (0.70, 0.90), "width": (0.70, 0.90)}))
        ,iaa.CropAndPad(percent=(-0.2, 0.2))
        #,iaa.PiecewiseAffine(scale=(0.01, 0.05))
        ,iaa.PerspectiveTransform(scale=(0.01, 0.1))
        #,iaa.WithPolarWarping(iaa.CropAndPad(percent=(-0.1, 0.1)))
        #,iaa.ElasticTransformation(alpha=(0, 3.0), sigma=0.5)
       ])
    #,iaa.SaveDebugImageEveryNBatches(folder_path, 100)    
], random_order=True)

# %%
def generator(features, labels, batch_size):
    while True:
        # Fill arrays of batch size with augmented data taken randomly from full passed arrays
        indexes = random.sample(range(len(features)), batch_size)
      
        # Transform X and y
        x_aug = seq(images =features[indexes])
        yield np.array(x_aug), np.array(labels[indexes])

# %%
images = generator(data_x,data_y, 9)
image = next(images)

plt.figure(figsize=(10, 10))
for i in range(9):
    ax = plt.subplot(3, 3, i + 1)
    #augmented_image = seq(images = x_train[:1])
    plt.imshow(image[0][i])
    plt.title(str(image[1][i]))
    plt.axis("off")
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %% [markdown]
# ## Transfer Learning

# %%
x_train, x_val, y_train, y_val = train_test_split(data_x, data_y, test_size=0.20, random_state=42)
y_train = np.argmax(y_train,axis=1)
y_val = np.argmax(y_val,axis=1)

# %%
from tensorflow.keras import applications
import logging
logging.basicConfig(filename='EfficientNet-AutoML.log')

model_list = ['EfficientNetB0', 'EfficientNetB1', 'EfficientNetB2', 'EfficientNetB3', 'EfficientNetB4', 'EfficientNetB5'
              , 'EfficientNetB6', 'EfficientNetB7','InceptionResNetV2']

for m in model_list:
    base_model = getattr(applicationspip , m)(weights='imagenet', input_shape=(image_size, image_size, 3),  include_top=False)

    # Create new model on top.
    inputs = keras.Input(shape=(image_size, image_size, 3))
    x = base_model(inputs, training=False)
    x = keras.layers.GlobalAveragePooling2D()(x)
    outputs = keras.layers.Dense(4)(x)
    model = keras.Model(inputs, outputs)
    model.summary()
    
    
    # Warm up head
    adam = optimizers.Adam(learning_rate=0.0005)
    #lr_scheduler = tf.keras.callbacks.LearningRateScheduler(scheduler)
    reduce_lr = ReduceLROnPlateau(monitor='val_loss', 
                               factor=0.2,  
                               patience=3, 
                               min_lr=0.00005)
    early_stop = EarlyStopping(
        monitor='val_loss', 
        min_delta=0, 
        patience=6, 
        verbose=0, 
        mode='auto',
        baseline=None, 
        restore_best_weights=True
    )

    batch_size = 64
    #num_warmup_steps = 5

    # freeze pretrained weights
    model.layers[1].trainable = False

    model.compile(optimizer=adam, 
                  loss=tf.keras.losses.SparseCategoricalCrossentropy(),
                  metrics=[tf.keras.metrics.SparseCategoricalCrossentropy()])


    history = model.fit(generator(x_train, y_train, batch_size),  
                        shuffle=True,  
                        validation_data = (x_val, y_val),
                        callbacks = [reduce_lr,early_stop],                        
                        epochs=100,
                        steps_per_epoch=len(x_train)/batch_size ,
                        verbose=True
                       )
    print(model.optimizer.lr)
    
    # Train entire network
    adam = optimizers.Adam(learning_rate=0.0001)
    #lr_scheduler = tf.keras.callbacks.LearningRateScheduler(scheduler)
    reduce_lr = ReduceLROnPlateau(monitor='val_accuracy', 
                               factor=0.2,  
                               patience=5 , 
                               min_lr=0.00001)
    early_stop = EarlyStopping(
        monitor='val_accuracy', 
        min_delta=0, 
        patience=10, 
        verbose=0, 
        mode='auto',
        baseline=None, 
        restore_best_weights=True
    )

    # freeze pretrained weights
    model.layers[1].trainable = True

    model.compile(optimizer=adam, 
                  loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
                  metrics=['accuracy'])

    history2 = model.fit(generator(x_train, y_train, batch_size),  
                        shuffle=True,  
                        validation_data = (x_val, y_val),
                        callbacks = [reduce_lr,early_stop],                        
                        epochs=200,
                        steps_per_epoch=len(x_train)/batch_size ,
                        verbose=True
                       )
    model.save(f'models/{m}')
    from sklearn.metrics import confusion_matrix
    import seaborn as sn
    import pandas as pd
    import matplotlib.pyplot as plt

    labels = ['healthy', 'multiple_diseases', 'rust', 'scab']
    y_val_pred = np.argmax(model.predict(x_val), axis=1)
    mat = confusion_matrix(y_val, y_val_pred)

    df_cm = pd.DataFrame(mat, index = [i for i in labels],
                      columns = [i for i in labels])
    plt.figure(figsize = (10,7))
    sn.heatmap(df_cm, annot=True)
    
    # Train on all data before inference
    model.fit(generator(x_val, y_val, batch_size),            
                        epochs=2,
                        steps_per_epoch=len(x_train)/batch_size ,
                        verbose=True
                       )
    
    labels = ['healthy', 'multiple_diseases', 'rust', 'scab']
    y_val_pred = np.argmax(model.predict(x_val), axis=1)
    mat = confusion_matrix(y_val, y_val_pred)

    df_cm = pd.DataFrame(mat, index = [i for i in labels],
                      columns = [i for i in labels])
    plt.figure(figsize = (10,7))
    sn.heatmap(df_cm, annot=True)
    
    # Load test data and their filename for submission file
    test_x, test_id  = load_data("Test") 
    test_y = model.predict(test_x)
    test_pred = tf.nn.softmax(test_y).numpy()
    test_set = np.hstack((test_id, test_pred))
    test_set = test_set[test_set[:,1].astype('uint16').argsort()]
    test_DF = pd.DataFrame(test_set, index=test_set[:,1], columns=["image_id","id","healthy","multiple_diseases","rust","scab"])
    test_DF[["image_id","healthy","multiple_diseases","rust","scab"]].to_csv(f'submissions/{m}.csv', index=False)
    
    file = f'submissions/{m}.csv'
    comments = f'"{m} baseline {date.today()}"'
    # !kaggle competitions submit -f$file  -m$comments plant-pathology-2020-fgvc7
    
    del model
    
    
# !kaggle competitions submissions plant-pathology-2020-fgvc7
# Out:
# Downloading data from https://storage.googleapis.com/keras-applications/efficientnetb0_notop.h5
# 16711680/16705208 [==============================] - 0s 0us/step
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_2 (InputLayer)         [(None, 224, 224, 3)]     0
# _________________________________________________________________
# efficientnetb0 (Functional)  (None, 7, 7, 1280)        4049571
# _________________________________________________________________
# global_average_pooling2d (Gl (None, 1280)              0
# _________________________________________________________________
# dense (Dense)                (None, 4)                 5124
# =================================================================
# Total params: 4,054,695
# Trainable params: 4,012,672
# Non-trainable params: 42,023
# _________________________________________________________________
# Epoch 1/100
# 22/22 [==============================] - 30s 1s/step - loss: 5.5036 - sparse_categorical_crossentropy: 5.5036 - val_loss: 1.5575 - val_sparse_categorical_crossentropy: 1.5575
# Epoch 2/100
# 22/22 [==============================] - 23s 1s/step - loss: 1.8449 - sparse_categorical_crossentropy: 1.8449 - val_loss: 1.4612 - val_sparse_categorical_crossentropy: 1.4612
# Epoch 3/100
# 22/22 [==============================] - 23s 1s/step - loss: 1.9666 - sparse_categorical_crossentropy: 1.9666 - val_loss: 1.4558 - val_sparse_categorical_crossentropy: 1.4558
# Epoch 4/100
# 22/22 [==============================] - 23s 1s/step - loss: 1.9400 - sparse_categorical_crossentropy: 1.9400 - val_loss: 1.4001 - val_sparse_categorical_crossentropy: 1.4001
# Epoch 5/100
# 22/22 [==============================] - 23s 1s/step - loss: 1.9328 - sparse_categorical_crossentropy: 1.9328 - val_loss: 1.2992 - val_sparse_categorical_crossentropy: 1.2992
# Epoch 6/100
# 22/22 [==============================] - 24s 1s/step - loss: 1.5863 - sparse_categorical_crossentropy: 1.5863 - val_loss: 1.4303 - val_sparse_categorical_crossentropy: 1.4303
# Epoch 7/100
# 22/22 [==============================] - 23s 1s/step - loss: 1.8137 - sparse_categorical_crossentropy: 1.8137 - val_loss: 1.2222 - val_sparse_categorical_crossentropy: 1.2222
# Epoch 8/100
# 22/22 [==============================] - 23s 1s/step - loss: 1.6722 - sparse_categorical_crossentropy: 1.6722 - val_loss: 1.4151 - val_sparse_categorical_crossentropy: 1.4151
# Epoch 9/100
# 22/22 [==============================] - 23s 1s/step - loss: 1.6825 - sparse_categorical_crossentropy: 1.6825 - val_loss: 1.5712 - val_sparse_categorical_crossentropy: 1.5712
# Epoch 10/100
# 22/22 [==============================] - 23s 1s/step - loss: 2.0382 - sparse_categorical_crossentropy: 2.0382 - val_loss: 2.0707 - val_sparse_categorical_crossentropy: 2.0707
# Epoch 11/100
# 22/22 [==============================] - 23s 1s/step - loss: 2.5606 - sparse_categorical_crossentropy: 2.5606 - val_loss: 1.3612 - val_sparse_categorical_crossentropy: 1.3612
# Epoch 12/100
# 22/22 [==============================] - 23s 1s/step - loss: 2.1678 - sparse_categorical_crossentropy: 2.1678 - val_loss: 1.3978 - val_sparse_categorical_crossentropy: 1.3978
# Epoch 13/100
# 22/22 [==============================] - 23s 1s/step - loss: 2.0364 - sparse_categorical_crossentropy: 2.0364 - val_loss: 1.3437 - val_sparse_categorical_crossentropy: 1.3437
# <tf.Variable 'Adam/learning_rate:0' shape=() dtype=float32, numpy=5e-05>
# Epoch 1/200
# 22/22 [==============================] - 89s 4s/step - loss: 0.7734 - accuracy: 0.7281 - val_loss: 0.3597 - val_accuracy: 0.8712
# Epoch 2/200
# 22/22 [==============================] - 81s 4s/step - loss: 0.2794 - accuracy: 0.9082 - val_loss: 0.2992 - val_accuracy: 0.9151
# Epoch 3/200
# 22/22 [==============================] - 81s 4s/step - loss: 0.2702 - accuracy: 0.9100 - val_loss: 0.2754 - val_accuracy: 0.9123
# Epoch 4/200
# 22/22 [==============================] - 80s 4s/step - loss: 0.1708 - accuracy: 0.9438 - val_loss: 0.2496 - val_accuracy: 0.9260
# Epoch 5/200
# 22/22 [==============================] - 80s 4s/step - loss: 0.1279 - accuracy: 0.9591 - val_loss: 0.2989 - val_accuracy: 0.9123
# Epoch 6/200
# 22/22 [==============================] - 80s 4s/step - loss: 0.1032 - accuracy: 0.9656 - val_loss: 0.3413 - val_accuracy: 0.9096
# Epoch 7/200
# 22/22 [==============================] - 80s 4s/step - loss: 0.1213 - accuracy: 0.9610 - val_loss: 0.2346 - val_accuracy: 0.9342
# Epoch 8/200
# 22/22 [==============================] - 80s 4s/step - loss: 0.1086 - accuracy: 0.9586 - val_loss: 0.2627 - val_accuracy: 0.9288
# Epoch 9/200
# 22/22 [==============================] - 80s 4s/step - loss: 0.0660 - accuracy: 0.9786 - val_loss: 0.3191 - val_accuracy: 0.9123
# Epoch 10/200
# 22/22 [==============================] - 80s 4s/step - loss: 0.0740 - accuracy: 0.9775 - val_loss: 0.2649 - val_accuracy: 0.9233
# Epoch 11/200
# 22/22 [==============================] - 80s 4s/step - loss: 0.0504 - accuracy: 0.9781 - val_loss: 0.2524 - val_accuracy: 0.9370
# Epoch 12/200
# 22/22 [==============================] - 81s 4s/step - loss: 0.0489 - accuracy: 0.9852 - val_loss: 0.3262 - val_accuracy: 0.9288
# Epoch 13/200
# 22/22 [==============================] - 81s 4s/step - loss: 0.0452 - accuracy: 0.9852 - val_loss: 0.3532 - val_accuracy: 0.9233
# Epoch 14/200
# 22/22 [==============================] - 81s 4s/step - loss: 0.0447 - accuracy: 0.9870 - val_loss: 0.2824 - val_accuracy: 0.9315
# Epoch 15/200
# 22/22 [==============================] - 81s 4s/step - loss: 0.0301 - accuracy: 0.9889 - val_loss: 0.4264 - val_accuracy: 0.9151
# Epoch 16/200
# 22/22 [==============================] - 81s 4s/step - loss: 0.0446 - accuracy: 0.9836 - val_loss: 0.3875 - val_accuracy: 0.9205
# Epoch 17/200
# 22/22 [==============================] - 81s 4s/step - loss: 0.0428 - accuracy: 0.9851 - val_loss: 0.2862 - val_accuracy: 0.9397
# Epoch 18/200
# 22/22 [==============================] - 81s 4s/step - loss: 0.0417 - accuracy: 0.9926 - val_loss: 0.3039 - val_accuracy: 0.9315
# Epoch 19/200
# 22/22 [==============================] - 81s 4s/step - loss: 0.0249 - accuracy: 0.9944 - val_loss: 0.2864 - val_accuracy: 0.9370
# Epoch 20/200
# 22/22 [==============================] - 80s 4s/step - loss: 0.0171 - accuracy: 0.9952 - val_loss: 0.3211 - val_accuracy: 0.9342
# Epoch 21/200
# 22/22 [==============================] - 81s 4s/step - loss: 0.0234 - accuracy: 0.9893 - val_loss: 0.3018 - val_accuracy: 0.9370
# Epoch 22/200
# 22/22 [==============================] - 81s 4s/step - loss: 0.0183 - accuracy: 0.9939 - val_loss: 0.3072 - val_accuracy: 0.9370
# Epoch 23/200
# 22/22 [==============================] - 80s 4s/step - loss: 0.0338 - accuracy: 0.9900 - val_loss: 0.2935 - val_accuracy: 0.9370
# Epoch 24/200
# 22/22 [==============================] - 80s 4s/step - loss: 0.0225 - accuracy: 0.9923 - val_loss: 0.3123 - val_accuracy: 0.9397
# Epoch 25/200
# 22/22 [==============================] - 81s 4s/step - loss: 0.0177 - accuracy: 0.9959 - val_loss: 0.2973 - val_accuracy: 0.9342
# Epoch 26/200
# 22/22 [==============================] - 80s 4s/step - loss: 0.0432 - accuracy: 0.9848 - val_loss: 0.3095 - val_accuracy: 0.9397
# Epoch 27/200
# 22/22 [==============================] - 80s 4s/step - loss: 0.0230 - accuracy: 0.9898 - val_loss: 0.2757 - val_accuracy: 0.9452
# Epoch 28/200
# 22/22 [==============================] - 79s 3s/step - loss: 0.0228 - accuracy: 0.9929 - val_loss: 0.2894 - val_accuracy: 0.9342
# Epoch 29/200
# 22/22 [==============================] - 79s 4s/step - loss: 0.0301 - accuracy: 0.9905 - val_loss: 0.3161 - val_accuracy: 0.9370
# Epoch 30/200
# 22/22 [==============================] - 80s 4s/step - loss: 0.0185 - accuracy: 0.9926 - val_loss: 0.3093 - val_accuracy: 0.9315
# Epoch 31/200
# 22/22 [==============================] - 79s 3s/step - loss: 0.0180 - accuracy: 0.9928 - val_loss: 0.2899 - val_accuracy: 0.9397
# Epoch 32/200
# 22/22 [==============================] - 79s 4s/step - loss: 0.0178 - accuracy: 0.9946 - val_loss: 0.2891 - val_accuracy: 0.9342
# Epoch 33/200
# 22/22 [==============================] - 79s 3s/step - loss: 0.0140 - accuracy: 0.9964 - val_loss: 0.2900 - val_accuracy: 0.9397
# Epoch 34/200
# 22/22 [==============================] - 79s 3s/step - loss: 0.0128 - accuracy: 0.9966 - val_loss: 0.3032 - val_accuracy: 0.9370
# Epoch 35/200
# 22/22 [==============================] - 81s 4s/step - loss: 0.0177 - accuracy: 0.9935 - val_loss: 0.3074 - val_accuracy: 0.9397
# Epoch 36/200
# 22/22 [==============================] - 80s 4s/step - loss: 0.0238 - accuracy: 0.9894 - val_loss: 0.2855 - val_accuracy: 0.9507
# Epoch 37/200
# 22/22 [==============================] - 81s 4s/step - loss: 0.0274 - accuracy: 0.9894 - val_loss: 0.2974 - val_accuracy: 0.9425
# Epoch 38/200
# 22/22 [==============================] - 80s 4s/step - loss: 0.0285 - accuracy: 0.9903 - val_loss: 0.2922 - val_accuracy: 0.9370
# Epoch 39/200
# 22/22 [==============================] - 80s 4s/step - loss: 0.0160 - accuracy: 0.9961 - val_loss: 0.2876 - val_accuracy: 0.9370
# Epoch 40/200
# 22/22 [==============================] - 79s 3s/step - loss: 0.0158 - accuracy: 0.9953 - val_loss: 0.3017 - val_accuracy: 0.9397
# Epoch 41/200
# 22/22 [==============================] - 79s 4s/step - loss: 0.0180 - accuracy: 0.9937 - val_loss: 0.3247 - val_accuracy: 0.9370
# Epoch 42/200
# 22/22 [==============================] - 79s 4s/step - loss: 0.0169 - accuracy: 0.9949 - val_loss: 0.3226 - val_accuracy: 0.9370
# Epoch 43/200
# 22/22 [==============================] - 79s 3s/step - loss: 0.0115 - accuracy: 0.9958 - val_loss: 0.2963 - val_accuracy: 0.9370
# Epoch 44/200
# 22/22 [==============================] - 79s 4s/step - loss: 0.0137 - accuracy: 0.9960 - val_loss: 0.3025 - val_accuracy: 0.9425
# Epoch 45/200
# 22/22 [==============================] - 80s 4s/step - loss: 0.0160 - accuracy: 0.9921 - val_loss: 0.2967 - val_accuracy: 0.9425
# Epoch 46/200
# 22/22 [==============================] - 80s 4s/step - loss: 0.0159 - accuracy: 0.9941 - val_loss: 0.2955 - val_accuracy: 0.9452
# INFO:tensorflow:Assets written to: models/EfficientNetB0/assets
# Epoch 1/2
# 22/22 [==============================] - 76s 3s/step - loss: 0.2260 - accuracy: 0.9402
# Epoch 2/2
# 22/22 [==============================] - 75s 3s/step - loss: 0.1091 - accuracy: 0.9681
# 100%|█████████████████████████████████████████| 105k/105k [00:00<00:00, 289kB/s]
# Successfully submitted to Plant Pathology 2020 - FGVC7Downloading data from https://storage.googleapis.com/keras-applications/efficientnetb1_notop.h5
# 27025408/27018416 [==============================] - 0s 0us/step
# Model: "model_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_4 (InputLayer)         [(None, 224, 224, 3)]     0
# _________________________________________________________________
# efficientnetb1 (Functional)  (None, 7, 7, 1280)        6575239
# _________________________________________________________________
# global_average_pooling2d_1 ( (None, 1280)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 4)                 5124
# =================================================================
# Total params: 6,580,363
# Trainable params: 6,518,308
# Non-trainable params: 62,055
# _________________________________________________________________
# Epoch 1/100
# 22/22 [==============================] - 40s 1s/step - loss: 5.0641 - sparse_categorical_crossentropy: 5.0641 - val_loss: 1.3877 - val_sparse_categorical_crossentropy: 1.3877
# Epoch 2/100
# 22/22 [==============================] - 31s 1s/step - loss: 1.6188 - sparse_categorical_crossentropy: 1.6188 - val_loss: 1.3787 - val_sparse_categorical_crossentropy: 1.3787
# Epoch 3/100
# 22/22 [==============================] - 31s 1s/step - loss: 1.4303 - sparse_categorical_crossentropy: 1.4303 - val_loss: 1.3825 - val_sparse_categorical_crossentropy: 1.3825
# Epoch 4/100
# 22/22 [==============================] - 31s 1s/step - loss: 1.4023 - sparse_categorical_crossentropy: 1.4023 - val_loss: 1.3825 - val_sparse_categorical_crossentropy: 1.3825
# Epoch 5/100
# 22/22 [==============================] - 30s 1s/step - loss: 1.3843 - sparse_categorical_crossentropy: 1.3843 - val_loss: 1.3825 - val_sparse_categorical_crossentropy: 1.3825
# Epoch 6/100
# 22/22 [==============================] - 31s 1s/step - loss: 1.4085 - sparse_categorical_crossentropy: 1.4085 - val_loss: 1.3825 - val_sparse_categorical_crossentropy: 1.3825
# Epoch 7/100
# 22/22 [==============================] - 31s 1s/step - loss: 1.3809 - sparse_categorical_crossentropy: 1.3809 - val_loss: 1.3825 - val_sparse_categorical_crossentropy: 1.3825
# Epoch 8/100
# 22/22 [==============================] - 31s 1s/step - loss: 1.3961 - sparse_categorical_crossentropy: 1.3961 - val_loss: 1.3825 - val_sparse_categorical_crossentropy: 1.3825
# <tf.Variable 'Adam/learning_rate:0' shape=() dtype=float32, numpy=5e-05>
# Epoch 1/200
# 22/22 [==============================] - 126s 5s/step - loss: 0.8927 - accuracy: 0.6787 - val_loss: 0.3005 - val_accuracy: 0.8986
# Epoch 2/200
# 22/22 [==============================] - 113s 5s/step - loss: 0.2846 - accuracy: 0.8984 - val_loss: 0.2838 - val_accuracy: 0.9178
# Epoch 3/200
# 22/22 [==============================] - 113s 5s/step - loss: 0.2047 - accuracy: 0.9298 - val_loss: 0.3828 - val_accuracy: 0.9041
# Epoch 4/200
# 22/22 [==============================] - 113s 5s/step - loss: 0.1740 - accuracy: 0.9402 - val_loss: 0.2560 - val_accuracy: 0.9178
# Epoch 5/200
# 22/22 [==============================] - 113s 5s/step - loss: 0.1143 - accuracy: 0.9630 - val_loss: 0.2284 - val_accuracy: 0.9288
# Epoch 6/200
# 22/22 [==============================] - 113s 5s/step - loss: 0.1427 - accuracy: 0.9612 - val_loss: 0.2199 - val_accuracy: 0.9178
# Epoch 7/200
# 22/22 [==============================] - 113s 5s/step - loss: 0.0911 - accuracy: 0.9664 - val_loss: 0.2582 - val_accuracy: 0.9260
# Epoch 8/200
# 22/22 [==============================] - 113s 5s/step - loss: 0.0593 - accuracy: 0.9864 - val_loss: 0.2671 - val_accuracy: 0.9205
# Epoch 9/200
# 22/22 [==============================] - 113s 5s/step - loss: 0.0749 - accuracy: 0.9761 - val_loss: 0.2999 - val_accuracy: 0.9260
# Epoch 10/200
# 22/22 [==============================] - 113s 5s/step - loss: 0.0526 - accuracy: 0.9849 - val_loss: 0.3130 - val_accuracy: 0.9041
# Epoch 11/200
# 22/22 [==============================] - 113s 5s/step - loss: 0.0490 - accuracy: 0.9881 - val_loss: 0.2214 - val_accuracy: 0.9370
# Epoch 12/200
# 22/22 [==============================] - 113s 5s/step - loss: 0.0434 - accuracy: 0.9846 - val_loss: 0.2116 - val_accuracy: 0.9479
# Epoch 13/200
# 22/22 [==============================] - 113s 5s/step - loss: 0.0344 - accuracy: 0.9911 - val_loss: 0.2012 - val_accuracy: 0.9370
# Epoch 14/200
# 22/22 [==============================] - 113s 5s/step - loss: 0.0229 - accuracy: 0.9940 - val_loss: 0.2189 - val_accuracy: 0.9342
# Epoch 15/200
# 22/22 [==============================] - 113s 5s/step - loss: 0.0260 - accuracy: 0.9916 - val_loss: 0.2308 - val_accuracy: 0.9315
# Epoch 16/200
# 22/22 [==============================] - 113s 5s/step - loss: 0.0271 - accuracy: 0.9894 - val_loss: 0.2705 - val_accuracy: 0.9260
# Epoch 17/200
# 22/22 [==============================] - 113s 5s/step - loss: 0.0352 - accuracy: 0.9883 - val_loss: 0.2310 - val_accuracy: 0.9370
# Epoch 18/200
# 22/22 [==============================] - 114s 5s/step - loss: 0.0365 - accuracy: 0.9871 - val_loss: 0.2663 - val_accuracy: 0.9288
# Epoch 19/200
# 22/22 [==============================] - 114s 5s/step - loss: 0.0203 - accuracy: 0.9953 - val_loss: 0.2430 - val_accuracy: 0.9397
# Epoch 20/200
# 22/22 [==============================] - 114s 5s/step - loss: 0.0331 - accuracy: 0.9917 - val_loss: 0.2623 - val_accuracy: 0.9342
# Epoch 21/200
# 22/22 [==============================] - 114s 5s/step - loss: 0.0306 - accuracy: 0.9895 - val_loss: 0.2448 - val_accuracy: 0.9342
# Epoch 22/200
# 22/22 [==============================] - 113s 5s/step - loss: 0.0242 - accuracy: 0.9951 - val_loss: 0.2446 - val_accuracy: 0.9342
# INFO:tensorflow:Assets written to: models/EfficientNetB1/assets
# Epoch 1/2
# 22/22 [==============================] - 107s 5s/step - loss: 0.1737 - accuracy: 0.9504
# Epoch 2/2
# 22/22 [==============================] - 107s 5s/step - loss: 0.1216 - accuracy: 0.9674
# 100%|█████████████████████████████████████████| 105k/105k [00:00<00:00, 255kB/s]
# Successfully submitted to Plant Pathology 2020 - FGVC7Downloading data from https://storage.googleapis.com/keras-applications/efficientnetb2_notop.h5
# 31793152/31790344 [==============================] - 0s 0us/step
# Model: "model_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_6 (InputLayer)         [(None, 224, 224, 3)]     0
# _________________________________________________________________
# efficientnetb2 (Functional)  (None, 7, 7, 1408)        7768569
# _________________________________________________________________
# global_average_pooling2d_2 ( (None, 1408)              0
# _________________________________________________________________
# dense_2 (Dense)              (None, 4)                 5636
# =================================================================
# Total params: 7,774,205
# Trainable params: 7,706,630
# Non-trainable params: 67,575
# _________________________________________________________________
# Epoch 1/100
# 22/22 [==============================] - 42s 2s/step - loss: 6.2583 - sparse_categorical_crossentropy: 6.2583 - val_loss: 3.8305 - val_sparse_categorical_crossentropy: 3.8305
# Epoch 2/100
# 22/22 [==============================] - 33s 1s/step - loss: 3.1388 - sparse_categorical_crossentropy: 3.1388 - val_loss: 1.6881 - val_sparse_categorical_crossentropy: 1.6881
# Epoch 3/100
# 22/22 [==============================] - 33s 1s/step - loss: 2.0322 - sparse_categorical_crossentropy: 2.0322 - val_loss: 1.5402 - val_sparse_categorical_crossentropy: 1.5402
# Epoch 4/100
# 22/22 [==============================] - 34s 1s/step - loss: 1.9576 - sparse_categorical_crossentropy: 1.9576 - val_loss: 1.5128 - val_sparse_categorical_crossentropy: 1.5128
# Epoch 5/100
# 22/22 [==============================] - 33s 1s/step - loss: 1.8951 - sparse_categorical_crossentropy: 1.8951 - val_loss: 1.4514 - val_sparse_categorical_crossentropy: 1.4514
# Epoch 6/100
# 22/22 [==============================] - 33s 1s/step - loss: 2.0449 - sparse_categorical_crossentropy: 2.0449 - val_loss: 2.5085 - val_sparse_categorical_crossentropy: 2.5085
# Epoch 7/100
# 22/22 [==============================] - 34s 1s/step - loss: 2.7173 - sparse_categorical_crossentropy: 2.7173 - val_loss: 1.3751 - val_sparse_categorical_crossentropy: 1.3751
# Epoch 8/100
# 22/22 [==============================] - 33s 1s/step - loss: 1.6033 - sparse_categorical_crossentropy: 1.6033 - val_loss: 1.4318 - val_sparse_categorical_crossentropy: 1.4318
# Epoch 9/100
# 22/22 [==============================] - 34s 1s/step - loss: 1.7366 - sparse_categorical_crossentropy: 1.7366 - val_loss: 1.2513 - val_sparse_categorical_crossentropy: 1.2513
# Epoch 10/100
# 22/22 [==============================] - 33s 1s/step - loss: 1.2228 - sparse_categorical_crossentropy: 1.2228 - val_loss: 1.2101 - val_sparse_categorical_crossentropy: 1.2101
# Epoch 11/100
# 22/22 [==============================] - 33s 1s/step - loss: 1.2972 - sparse_categorical_crossentropy: 1.2972 - val_loss: 1.0911 - val_sparse_categorical_crossentropy: 1.0911
# Epoch 12/100
# 22/22 [==============================] - 33s 1s/step - loss: 1.2012 - sparse_categorical_crossentropy: 1.2012 - val_loss: 1.0941 - val_sparse_categorical_crossentropy: 1.0941
# Epoch 13/100
# 22/22 [==============================] - 33s 1s/step - loss: 1.1734 - sparse_categorical_crossentropy: 1.1734 - val_loss: 1.1298 - val_sparse_categorical_crossentropy: 1.1298
# Epoch 14/100
# 22/22 [==============================] - 34s 1s/step - loss: 1.1499 - sparse_categorical_crossentropy: 1.1499 - val_loss: 1.0676 - val_sparse_categorical_crossentropy: 1.0676
# Epoch 15/100
# 22/22 [==============================] - 34s 2s/step - loss: 1.1809 - sparse_categorical_crossentropy: 1.1809 - val_loss: 1.1098 - val_sparse_categorical_crossentropy: 1.1098
# Epoch 16/100
# 22/22 [==============================] - 33s 1s/step - loss: 1.2302 - sparse_categorical_crossentropy: 1.2302 - val_loss: 1.1910 - val_sparse_categorical_crossentropy: 1.1910
# Epoch 17/100
# 22/22 [==============================] - 34s 1s/step - loss: 1.2289 - sparse_categorical_crossentropy: 1.2289 - val_loss: 1.1117 - val_sparse_categorical_crossentropy: 1.1117
# Epoch 18/100
# 22/22 [==============================] - 33s 1s/step - loss: 1.1413 - sparse_categorical_crossentropy: 1.1413 - val_loss: 1.0976 - val_sparse_categorical_crossentropy: 1.0976
# Epoch 19/100
# 22/22 [==============================] - 33s 1s/step - loss: 1.3285 - sparse_categorical_crossentropy: 1.3285 - val_loss: 1.0967 - val_sparse_categorical_crossentropy: 1.0967
# Epoch 20/100
# 22/22 [==============================] - 34s 1s/step - loss: 1.2195 - sparse_categorical_crossentropy: 1.2195 - val_loss: 1.0889 - val_sparse_categorical_crossentropy: 1.0889
# <tf.Variable 'Adam/learning_rate:0' shape=() dtype=float32, numpy=5e-05>
# Epoch 1/200
# 22/22 [==============================] - 133s 5s/step - loss: 0.7207 - accuracy: 0.7513 - val_loss: 0.2744 - val_accuracy: 0.9151
# Epoch 2/200
# 22/22 [==============================] - 120s 5s/step - loss: 0.2774 - accuracy: 0.9045 - val_loss: 0.2819 - val_accuracy: 0.9233
# Epoch 3/200
# 22/22 [==============================] - 120s 5s/step - loss: 0.1767 - accuracy: 0.9444 - val_loss: 0.2950 - val_accuracy: 0.9123
# Epoch 4/200
# 22/22 [==============================] - 119s 5s/step - loss: 0.1179 - accuracy: 0.9661 - val_loss: 0.2524 - val_accuracy: 0.9205
# Epoch 5/200
# 22/22 [==============================] - 119s 5s/step - loss: 0.1136 - accuracy: 0.9585 - val_loss: 0.2707 - val_accuracy: 0.9233
# Epoch 6/200
# 22/22 [==============================] - 119s 5s/step - loss: 0.0873 - accuracy: 0.9744 - val_loss: 0.2618 - val_accuracy: 0.9397
# Epoch 7/200
# 22/22 [==============================] - 119s 5s/step - loss: 0.0891 - accuracy: 0.9748 - val_loss: 0.3335 - val_accuracy: 0.9151
# Epoch 8/200
# 22/22 [==============================] - 119s 5s/step - loss: 0.0675 - accuracy: 0.9778 - val_loss: 0.2811 - val_accuracy: 0.9315
# Epoch 9/200
# 22/22 [==============================] - 119s 5s/step - loss: 0.0411 - accuracy: 0.9829 - val_loss: 0.2931 - val_accuracy: 0.9370
# Epoch 10/200
# 22/22 [==============================] - 119s 5s/step - loss: 0.0569 - accuracy: 0.9858 - val_loss: 0.4602 - val_accuracy: 0.9041
# Epoch 11/200
# 22/22 [==============================] - 118s 5s/step - loss: 0.0467 - accuracy: 0.9845 - val_loss: 0.2538 - val_accuracy: 0.9452
# Epoch 12/200
# 22/22 [==============================] - 118s 5s/step - loss: 0.0364 - accuracy: 0.9873 - val_loss: 0.3533 - val_accuracy: 0.9370
# Epoch 13/200
# 22/22 [==============================] - 117s 5s/step - loss: 0.0576 - accuracy: 0.9863 - val_loss: 0.2763 - val_accuracy: 0.9452
# Epoch 14/200
# 22/22 [==============================] - 118s 5s/step - loss: 0.0638 - accuracy: 0.9808 - val_loss: 0.3898 - val_accuracy: 0.9260
# Epoch 15/200
# 22/22 [==============================] - 117s 5s/step - loss: 0.0479 - accuracy: 0.9807 - val_loss: 0.2904 - val_accuracy: 0.9315
# Epoch 16/200
# 22/22 [==============================] - 117s 5s/step - loss: 0.0212 - accuracy: 0.9942 - val_loss: 0.2584 - val_accuracy: 0.9452
# Epoch 17/200
# 22/22 [==============================] - 117s 5s/step - loss: 0.0301 - accuracy: 0.9890 - val_loss: 0.2676 - val_accuracy: 0.9452
# Epoch 18/200
# 22/22 [==============================] - 117s 5s/step - loss: 0.0168 - accuracy: 0.9935 - val_loss: 0.2766 - val_accuracy: 0.9425
# Epoch 19/200
# 22/22 [==============================] - 117s 5s/step - loss: 0.0068 - accuracy: 0.9980 - val_loss: 0.2967 - val_accuracy: 0.9370
# Epoch 20/200
# 22/22 [==============================] - 117s 5s/step - loss: 0.0121 - accuracy: 0.9959 - val_loss: 0.2762 - val_accuracy: 0.9452
# Epoch 21/200
# 22/22 [==============================] - 118s 5s/step - loss: 0.0104 - accuracy: 0.9965 - val_loss: 0.3301 - val_accuracy: 0.9315
# INFO:tensorflow:Assets written to: models/EfficientNetB2/assets
# Epoch 1/2
# 22/22 [==============================] - 111s 5s/step - loss: 0.1973 - accuracy: 0.9504
# Epoch 2/2
# 22/22 [==============================] - 110s 5s/step - loss: 0.1201 - accuracy: 0.9681
# 100%|█████████████████████████████████████████| 105k/105k [00:00<00:00, 163kB/s]
# Successfully submitted to Plant Pathology 2020 - FGVC7Downloading data from https://storage.googleapis.com/keras-applications/efficientnetb3_notop.h5
# 43941888/43941136 [==============================] - 0s 0us/step
# Model: "model_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_8 (InputLayer)         [(None, 224, 224, 3)]     0
# _________________________________________________________________
# efficientnetb3 (Functional)  (None, 7, 7, 1536)        10783535
# _________________________________________________________________
# global_average_pooling2d_3 ( (None, 1536)              0
# _________________________________________________________________
# dense_3 (Dense)              (None, 4)                 6148
# =================================================================
# Total params: 10,789,683
# Trainable params: 10,702,380
# Non-trainable params: 87,303
# _________________________________________________________________
# Epoch 1/100
# 22/22 [==============================] - 54s 2s/step - loss: 4.1721 - sparse_categorical_crossentropy: 4.1721 - val_loss: 1.3908 - val_sparse_categorical_crossentropy: 1.3908
# Epoch 2/100
# 22/22 [==============================] - 43s 2s/step - loss: 1.6867 - sparse_categorical_crossentropy: 1.6867 - val_loss: 1.1965 - val_sparse_categorical_crossentropy: 1.1965
# Epoch 3/100
# 22/22 [==============================] - 43s 2s/step - loss: 1.3136 - sparse_categorical_crossentropy: 1.3136 - val_loss: 1.2234 - val_sparse_categorical_crossentropy: 1.2234
# Epoch 4/100
# 22/22 [==============================] - 43s 2s/step - loss: 1.2511 - sparse_categorical_crossentropy: 1.2511 - val_loss: 1.1138 - val_sparse_categorical_crossentropy: 1.1138
# Epoch 5/100
# 22/22 [==============================] - 43s 2s/step - loss: 1.2786 - sparse_categorical_crossentropy: 1.2786 - val_loss: 1.1451 - val_sparse_categorical_crossentropy: 1.1451
# Epoch 6/100
# 22/22 [==============================] - 43s 2s/step - loss: 1.1972 - sparse_categorical_crossentropy: 1.1972 - val_loss: 1.1050 - val_sparse_categorical_crossentropy: 1.1050
# Epoch 7/100
# 22/22 [==============================] - 43s 2s/step - loss: 1.2738 - sparse_categorical_crossentropy: 1.2738 - val_loss: 1.1631 - val_sparse_categorical_crossentropy: 1.1631
# Epoch 8/100
# 22/22 [==============================] - 43s 2s/step - loss: 1.2166 - sparse_categorical_crossentropy: 1.2166 - val_loss: 0.9790 - val_sparse_categorical_crossentropy: 0.9790
# Epoch 9/100
# 22/22 [==============================] - 43s 2s/step - loss: 1.2797 - sparse_categorical_crossentropy: 1.2797 - val_loss: 1.1200 - val_sparse_categorical_crossentropy: 1.1200
# Epoch 10/100
# 22/22 [==============================] - 43s 2s/step - loss: 0.9952 - sparse_categorical_crossentropy: 0.9952 - val_loss: 0.9548 - val_sparse_categorical_crossentropy: 0.9548
# Epoch 11/100
# 22/22 [==============================] - 43s 2s/step - loss: 1.1365 - sparse_categorical_crossentropy: 1.1365 - val_loss: 0.9107 - val_sparse_categorical_crossentropy: 0.9107
# Epoch 12/100
# 22/22 [==============================] - 43s 2s/step - loss: 1.0584 - sparse_categorical_crossentropy: 1.0584 - val_loss: 0.8876 - val_sparse_categorical_crossentropy: 0.8876
# Epoch 13/100
# 22/22 [==============================] - 44s 2s/step - loss: 0.9777 - sparse_categorical_crossentropy: 0.9777 - val_loss: 0.8678 - val_sparse_categorical_crossentropy: 0.8678
# Epoch 14/100
# 22/22 [==============================] - 43s 2s/step - loss: 1.0153 - sparse_categorical_crossentropy: 1.0153 - val_loss: 0.8331 - val_sparse_categorical_crossentropy: 0.8331
# Epoch 15/100
# 22/22 [==============================] - 43s 2s/step - loss: 0.9962 - sparse_categorical_crossentropy: 0.9962 - val_loss: 0.8823 - val_sparse_categorical_crossentropy: 0.8823
# Epoch 16/100
# 22/22 [==============================] - 43s 2s/step - loss: 1.0063 - sparse_categorical_crossentropy: 1.0063 - val_loss: 0.8297 - val_sparse_categorical_crossentropy: 0.8297
# Epoch 17/100
# 22/22 [==============================] - 44s 2s/step - loss: 1.0172 - sparse_categorical_crossentropy: 1.0172 - val_loss: 0.7952 - val_sparse_categorical_crossentropy: 0.7952
# Epoch 18/100
# 22/22 [==============================] - 43s 2s/step - loss: 1.0218 - sparse_categorical_crossentropy: 1.0218 - val_loss: 0.8183 - val_sparse_categorical_crossentropy: 0.8183
# Epoch 19/100
# 22/22 [==============================] - 43s 2s/step - loss: 0.9531 - sparse_categorical_crossentropy: 0.9531 - val_loss: 0.9770 - val_sparse_categorical_crossentropy: 0.9770
# Epoch 20/100
# 22/22 [==============================] - 43s 2s/step - loss: 1.0244 - sparse_categorical_crossentropy: 1.0244 - val_loss: 1.3018 - val_sparse_categorical_crossentropy: 1.3018
# Epoch 21/100
# 22/22 [==============================] - 43s 2s/step - loss: 1.1999 - sparse_categorical_crossentropy: 1.1999 - val_loss: 1.2548 - val_sparse_categorical_crossentropy: 1.2548
# Epoch 22/100
# 22/22 [==============================] - 43s 2s/step - loss: 1.1899 - sparse_categorical_crossentropy: 1.1899 - val_loss: 1.2319 - val_sparse_categorical_crossentropy: 1.2319
# Epoch 23/100
# 22/22 [==============================] - 43s 2s/step - loss: 1.1611 - sparse_categorical_crossentropy: 1.1611 - val_loss: 1.2064 - val_sparse_categorical_crossentropy: 1.2064
# <tf.Variable 'Adam/learning_rate:0' shape=() dtype=float32, numpy=5e-05>
# Epoch 1/200
# 22/22 [==============================] - 173s 7s/step - loss: 0.6063 - accuracy: 0.8240 - val_loss: 0.3174 - val_accuracy: 0.9014
# Epoch 2/200
# 22/22 [==============================] - 160s 7s/step - loss: 0.2348 - accuracy: 0.9136 - val_loss: 0.2112 - val_accuracy: 0.9370
# Epoch 3/200
# 22/22 [==============================] - 160s 7s/step - loss: 0.1350 - accuracy: 0.9510 - val_loss: 0.1607 - val_accuracy: 0.9479
# Epoch 4/200
# 22/22 [==============================] - 159s 7s/step - loss: 0.1341 - accuracy: 0.9556 - val_loss: 0.1727 - val_accuracy: 0.9479
# Epoch 5/200
# 22/22 [==============================] - 160s 7s/step - loss: 0.1142 - accuracy: 0.9626 - val_loss: 0.1500 - val_accuracy: 0.9616
# Epoch 6/200
# 22/22 [==============================] - 159s 7s/step - loss: 0.0642 - accuracy: 0.9801 - val_loss: 0.1873 - val_accuracy: 0.9507
# Epoch 7/200
# 22/22 [==============================] - 160s 7s/step - loss: 0.0662 - accuracy: 0.9817 - val_loss: 0.1757 - val_accuracy: 0.9534
# Epoch 8/200
# 22/22 [==============================] - 159s 7s/step - loss: 0.0520 - accuracy: 0.9848 - val_loss: 0.2025 - val_accuracy: 0.9507
# Epoch 9/200
# 22/22 [==============================] - 158s 7s/step - loss: 0.0547 - accuracy: 0.9826 - val_loss: 0.2224 - val_accuracy: 0.9452
# Epoch 10/200
# 22/22 [==============================] - 158s 7s/step - loss: 0.0331 - accuracy: 0.9909 - val_loss: 0.2141 - val_accuracy: 0.9534
# Epoch 11/200
# 22/22 [==============================] - 157s 7s/step - loss: 0.0252 - accuracy: 0.9914 - val_loss: 0.1953 - val_accuracy: 0.9479
# Epoch 12/200
# 22/22 [==============================] - 158s 7s/step - loss: 0.0416 - accuracy: 0.9889 - val_loss: 0.1753 - val_accuracy: 0.9507
# Epoch 13/200
# 22/22 [==============================] - 158s 7s/step - loss: 0.0222 - accuracy: 0.9928 - val_loss: 0.1840 - val_accuracy: 0.9479
# Epoch 14/200
# 22/22 [==============================] - 159s 7s/step - loss: 0.0276 - accuracy: 0.9928 - val_loss: 0.1709 - val_accuracy: 0.9616
# Epoch 15/200
# 22/22 [==============================] - 157s 7s/step - loss: 0.0255 - accuracy: 0.9901 - val_loss: 0.1678 - val_accuracy: 0.9479
# INFO:tensorflow:Assets written to: models/EfficientNetB3/assets
# Epoch 1/2
# 22/22 [==============================] - 149s 7s/step - loss: 0.1403 - accuracy: 0.9558
# Epoch 2/2
# 22/22 [==============================] - 150s 7s/step - loss: 0.0989 - accuracy: 0.9742
# 100%|█████████████████████████████████████████| 104k/104k [00:00<00:00, 229kB/s]
# Successfully submitted to Plant Pathology 2020 - FGVC7Downloading data from https://storage.googleapis.com/keras-applications/efficientnetb4_notop.h5
# 71688192/71686520 [==============================] - 1s 0us/step
# Model: "model_4"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_10 (InputLayer)        [(None, 224, 224, 3)]     0
# _________________________________________________________________
# efficientnetb4 (Functional)  (None, 7, 7, 1792)        17673823
# _________________________________________________________________
# global_average_pooling2d_4 ( (None, 1792)              0
# _________________________________________________________________
# dense_4 (Dense)              (None, 4)                 7172
# =================================================================
# Total params: 17,680,995
# Trainable params: 17,555,788
# Non-trainable params: 125,207
# _________________________________________________________________
# Epoch 1/100
# 22/22 [==============================] - 72s 3s/step - loss: 4.6522 - sparse_categorical_crossentropy: 4.6522 - val_loss: 1.3863 - val_sparse_categorical_crossentropy: 1.3863
# Epoch 2/100
# 22/22 [==============================] - 59s 3s/step - loss: 1.4583 - sparse_categorical_crossentropy: 1.4583 - val_loss: 1.3863 - val_sparse_categorical_crossentropy: 1.3863
# Epoch 3/100
# 22/22 [==============================] - 59s 3s/step - loss: 1.3968 - sparse_categorical_crossentropy: 1.3968 - val_loss: 1.3863 - val_sparse_categorical_crossentropy: 1.3863
# Epoch 4/100
# 22/22 [==============================] - 59s 3s/step - loss: 1.4040 - sparse_categorical_crossentropy: 1.4040 - val_loss: 1.3863 - val_sparse_categorical_crossentropy: 1.3863
# Epoch 5/100
# 22/22 [==============================] - 59s 3s/step - loss: 1.3938 - sparse_categorical_crossentropy: 1.3938 - val_loss: 1.3863 - val_sparse_categorical_crossentropy: 1.3863
# Epoch 6/100
# 22/22 [==============================] - 59s 3s/step - loss: 1.3848 - sparse_categorical_crossentropy: 1.3848 - val_loss: 1.3863 - val_sparse_categorical_crossentropy: 1.3863
# Epoch 7/100
# 22/22 [==============================] - 59s 3s/step - loss: 1.4117 - sparse_categorical_crossentropy: 1.4117 - val_loss: 1.3863 - val_sparse_categorical_crossentropy: 1.3863
# <tf.Variable 'Adam/learning_rate:0' shape=() dtype=float32, numpy=5e-05>
# Epoch 1/200
# 22/22 [==============================] - 234s 10s/step - loss: 0.9586 - accuracy: 0.6070 - val_loss: 0.5457 - val_accuracy: 0.8110
# Epoch 2/200
# 22/22 [==============================] - 218s 10s/step - loss: 0.3404 - accuracy: 0.8775 - val_loss: 0.3110 - val_accuracy: 0.8986
# Epoch 3/200
# 22/22 [==============================] - 218s 10s/step - loss: 0.1647 - accuracy: 0.9446 - val_loss: 0.3834 - val_accuracy: 0.8877
# Epoch 4/200
# 22/22 [==============================] - 218s 10s/step - loss: 0.1500 - accuracy: 0.9514 - val_loss: 0.2167 - val_accuracy: 0.9123
# Epoch 5/200
# 22/22 [==============================] - 218s 10s/step - loss: 0.0989 - accuracy: 0.9693 - val_loss: 0.3004 - val_accuracy: 0.9178
# Epoch 6/200
# 22/22 [==============================] - 218s 10s/step - loss: 0.0948 - accuracy: 0.9743 - val_loss: 0.2798 - val_accuracy: 0.9014
# Epoch 7/200
# 22/22 [==============================] - 218s 10s/step - loss: 0.0768 - accuracy: 0.9816 - val_loss: 0.2489 - val_accuracy: 0.9233
# Epoch 8/200
# 22/22 [==============================] - 218s 10s/step - loss: 0.0526 - accuracy: 0.9805 - val_loss: 0.2417 - val_accuracy: 0.9260
# Epoch 9/200
# 22/22 [==============================] - 218s 10s/step - loss: 0.0320 - accuracy: 0.9925 - val_loss: 0.2558 - val_accuracy: 0.9233
# Epoch 10/200
# 22/22 [==============================] - 218s 10s/step - loss: 0.0275 - accuracy: 0.9900 - val_loss: 0.3732 - val_accuracy: 0.9151
# Epoch 11/200
# 22/22 [==============================] - 218s 10s/step - loss: 0.0542 - accuracy: 0.9875 - val_loss: 0.2891 - val_accuracy: 0.9205
# Epoch 12/200
# 22/22 [==============================] - 219s 10s/step - loss: 0.0357 - accuracy: 0.9857 - val_loss: 0.2613 - val_accuracy: 0.9315
# Epoch 13/200
# 22/22 [==============================] - 218s 10s/step - loss: 0.0455 - accuracy: 0.9827 - val_loss: 0.2581 - val_accuracy: 0.9315
# Epoch 14/200
# 22/22 [==============================] - 218s 10s/step - loss: 0.0232 - accuracy: 0.9936 - val_loss: 0.2886 - val_accuracy: 0.9342
# Epoch 15/200
# 22/22 [==============================] - 218s 10s/step - loss: 0.0164 - accuracy: 0.9939 - val_loss: 0.4369 - val_accuracy: 0.9288
# Epoch 16/200
# 22/22 [==============================] - 218s 10s/step - loss: 0.0266 - accuracy: 0.9908 - val_loss: 0.2873 - val_accuracy: 0.9370
# Epoch 17/200
# 22/22 [==============================] - 218s 10s/step - loss: 0.0238 - accuracy: 0.9928 - val_loss: 0.4137 - val_accuracy: 0.9041
# Epoch 18/200
# 22/22 [==============================] - 218s 10s/step - loss: 0.0165 - accuracy: 0.9973 - val_loss: 0.2655 - val_accuracy: 0.9479
# Epoch 19/200
# 22/22 [==============================] - 218s 10s/step - loss: 0.0152 - accuracy: 0.9964 - val_loss: 0.3426 - val_accuracy: 0.9315
# Epoch 20/200
# 22/22 [==============================] - 217s 10s/step - loss: 0.0348 - accuracy: 0.9885 - val_loss: 0.2359 - val_accuracy: 0.9370
# Epoch 21/200
# 22/22 [==============================] - 218s 10s/step - loss: 0.0124 - accuracy: 0.9943 - val_loss: 0.3540 - val_accuracy: 0.9205
# Epoch 22/200
# 22/22 [==============================] - 218s 10s/step - loss: 0.0292 - accuracy: 0.9912 - val_loss: 0.2486 - val_accuracy: 0.9260
# Epoch 23/200
# 22/22 [==============================] - 219s 10s/step - loss: 0.0142 - accuracy: 0.9971 - val_loss: 0.2739 - val_accuracy: 0.9425
# Epoch 24/200
# 22/22 [==============================] - 218s 10s/step - loss: 0.0110 - accuracy: 0.9985 - val_loss: 0.2791 - val_accuracy: 0.9452
# Epoch 25/200
# 22/22 [==============================] - 218s 10s/step - loss: 0.0106 - accuracy: 0.9971 - val_loss: 0.2667 - val_accuracy: 0.9452
# Epoch 26/200
# 22/22 [==============================] - 218s 10s/step - loss: 0.0246 - accuracy: 0.9942 - val_loss: 0.2553 - val_accuracy: 0.9479
# Epoch 27/200
# 22/22 [==============================] - 219s 10s/step - loss: 0.0204 - accuracy: 0.9936 - val_loss: 0.2596 - val_accuracy: 0.9479
# Epoch 28/200
# 22/22 [==============================] - 219s 10s/step - loss: 0.0214 - accuracy: 0.9948 - val_loss: 0.2473 - val_accuracy: 0.9452
# INFO:tensorflow:Assets written to: models/EfficientNetB4/assets
# Epoch 1/2
# 22/22 [==============================] - 207s 9s/step - loss: 0.2228 - accuracy: 0.9457
# Epoch 2/2
# 22/22 [==============================] - 207s 9s/step - loss: 0.0908 - accuracy: 0.9721
# 100%|█████████████████████████████████████████| 105k/105k [00:00<00:00, 219kB/s]
# Successfully submitted to Plant Pathology 2020 - FGVC7Downloading data from https://storage.googleapis.com/keras-applications/efficientnetb5_notop.h5
# 115269632/115263384 [==============================] - 1s 0us/step
# Model: "model_5"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_12 (InputLayer)        [(None, 224, 224, 3)]     0
# _________________________________________________________________
# efficientnetb5 (Functional)  (None, 7, 7, 2048)        28513527
# _________________________________________________________________
# global_average_pooling2d_5 ( (None, 2048)              0
# _________________________________________________________________
# dense_5 (Dense)              (None, 4)                 8196
# =================================================================
# Total params: 28,521,723
# Trainable params: 28,348,980
# Non-trainable params: 172,743
# _________________________________________________________________
# Epoch 1/100
# 22/22 [==============================] - 100s 4s/step - loss: 4.1565 - sparse_categorical_crossentropy: 4.1565 - val_loss: 1.4203 - val_sparse_categorical_crossentropy: 1.4203
# Epoch 2/100
# 22/22 [==============================] - 83s 4s/step - loss: 1.4265 - sparse_categorical_crossentropy: 1.4265 - val_loss: 1.3863 - val_sparse_categorical_crossentropy: 1.3863
# Epoch 3/100
# 22/22 [==============================] - 83s 4s/step - loss: 1.4203 - sparse_categorical_crossentropy: 1.4203 - val_loss: 1.3863 - val_sparse_categorical_crossentropy: 1.3863
# Epoch 4/100
# 22/22 [==============================] - 83s 4s/step - loss: 1.4059 - sparse_categorical_crossentropy: 1.4059 - val_loss: 1.3863 - val_sparse_categorical_crossentropy: 1.3863
# Epoch 5/100
# 22/22 [==============================] - 83s 4s/step - loss: 1.3936 - sparse_categorical_crossentropy: 1.3936 - val_loss: 1.3863 - val_sparse_categorical_crossentropy: 1.3863
# Epoch 6/100
# 22/22 [==============================] - 83s 4s/step - loss: 1.3863 - sparse_categorical_crossentropy: 1.3863 - val_loss: 1.3863 - val_sparse_categorical_crossentropy: 1.3863
# Epoch 7/100
# 22/22 [==============================] - 83s 4s/step - loss: 1.4354 - sparse_categorical_crossentropy: 1.4354 - val_loss: 1.3863 - val_sparse_categorical_crossentropy: 1.3863
# Epoch 8/100
# 22/22 [==============================] - 83s 4s/step - loss: 1.3860 - sparse_categorical_crossentropy: 1.3860 - val_loss: 1.3863 - val_sparse_categorical_crossentropy: 1.3863
# <tf.Variable 'Adam/learning_rate:0' shape=() dtype=float32, numpy=5e-05>
# Epoch 1/200
# 22/22 [==============================] - 345s 14s/step - loss: 0.9590 - accuracy: 0.5924 - val_loss: 0.2922 - val_accuracy: 0.9096
# Epoch 2/200
# 22/22 [==============================] - 324s 14s/step - loss: 0.2060 - accuracy: 0.9302 - val_loss: 0.2918 - val_accuracy: 0.9041
# Epoch 3/200
# 22/22 [==============================] - 325s 14s/step - loss: 0.1788 - accuracy: 0.9479 - val_loss: 0.3739 - val_accuracy: 0.8959
# Epoch 4/200
# 22/22 [==============================] - 325s 14s/step - loss: 0.1642 - accuracy: 0.9449 - val_loss: 0.2426 - val_accuracy: 0.9260
# Epoch 5/200
# 22/22 [==============================] - 324s 14s/step - loss: 0.1021 - accuracy: 0.9728 - val_loss: 0.1945 - val_accuracy: 0.9370
# Epoch 6/200
# 22/22 [==============================] - 325s 14s/step - loss: 0.0614 - accuracy: 0.9776 - val_loss: 0.3556 - val_accuracy: 0.9205
# Epoch 7/200
# 22/22 [==============================] - 327s 14s/step - loss: 0.0807 - accuracy: 0.9796 - val_loss: 0.3028 - val_accuracy: 0.9260
# Epoch 8/200
# 22/22 [==============================] - 324s 14s/step - loss: 0.0583 - accuracy: 0.9778 - val_loss: 0.3412 - val_accuracy: 0.9151
# Epoch 9/200
# 22/22 [==============================] - 324s 14s/step - loss: 0.0621 - accuracy: 0.9828 - val_loss: 0.2297 - val_accuracy: 0.9370
# Epoch 10/200
# 22/22 [==============================] - 325s 14s/step - loss: 0.0633 - accuracy: 0.9846 - val_loss: 0.2593 - val_accuracy: 0.9288
# Epoch 11/200
# 22/22 [==============================] - 325s 14s/step - loss: 0.0245 - accuracy: 0.9940 - val_loss: 0.1979 - val_accuracy: 0.9425
# Epoch 12/200
# 22/22 [==============================] - 324s 14s/step - loss: 0.0168 - accuracy: 0.9934 - val_loss: 0.2438 - val_accuracy: 0.9233
# Epoch 13/200
# 22/22 [==============================] - 324s 14s/step - loss: 0.0192 - accuracy: 0.9956 - val_loss: 0.2213 - val_accuracy: 0.9397
# Epoch 14/200
# 22/22 [==============================] - 325s 14s/step - loss: 0.0173 - accuracy: 0.9921 - val_loss: 0.2741 - val_accuracy: 0.9342
# Epoch 15/200
# 22/22 [==============================] - 325s 14s/step - loss: 0.0139 - accuracy: 0.9932 - val_loss: 0.2493 - val_accuracy: 0.9315
# Epoch 16/200
# 22/22 [==============================] - 324s 14s/step - loss: 0.0186 - accuracy: 0.9922 - val_loss: 0.2327 - val_accuracy: 0.9397
# Epoch 17/200
# 22/22 [==============================] - 324s 14s/step - loss: 0.0223 - accuracy: 0.9944 - val_loss: 0.2365 - val_accuracy: 0.9315
# Epoch 18/200
# 22/22 [==============================] - 325s 14s/step - loss: 0.0207 - accuracy: 0.9949 - val_loss: 0.2616 - val_accuracy: 0.9315
# Epoch 19/200
# 22/22 [==============================] - 324s 14s/step - loss: 0.0138 - accuracy: 0.9937 - val_loss: 0.2758 - val_accuracy: 0.9315
# Epoch 20/200
# 22/22 [==============================] - 325s 14s/step - loss: 0.0098 - accuracy: 0.9988 - val_loss: 0.2645 - val_accuracy: 0.9315
# Epoch 21/200
# 22/22 [==============================] - 325s 14s/step - loss: 0.0166 - accuracy: 0.9944 - val_loss: 0.2462 - val_accuracy: 0.9342
# INFO:tensorflow:Assets written to: models/EfficientNetB5/assets
# Epoch 1/2
# 22/22 [==============================] - 309s 14s/step - loss: 0.1670 - accuracy: 0.9477
# Epoch 2/2
# 22/22 [==============================] - 308s 14s/step - loss: 0.0707 - accuracy: 0.9769
# 100%|█████████████████████████████████████████| 105k/105k [00:00<00:00, 236kB/s]
# Successfully submitted to Plant Pathology 2020 - FGVC7Downloading data from https://storage.googleapis.com/keras-applications/efficientnetb6_notop.h5
# 165240832/165234480 [==============================] - 1s 0us/step
# Model: "model_6"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_14 (InputLayer)        [(None, 224, 224, 3)]     0
# _________________________________________________________________
# efficientnetb6 (Functional)  (None, 7, 7, 2304)        40960143
# _________________________________________________________________
# global_average_pooling2d_6 ( (None, 2304)              0
# _________________________________________________________________
# dense_6 (Dense)              (None, 4)                 9220
# =================================================================
# Total params: 40,969,363
# Trainable params: 40,744,924
# Non-trainable params: 224,439
# _________________________________________________________________
# Epoch 1/100
# 22/22 [==============================] - 129s 5s/step - loss: 4.4810 - sparse_categorical_crossentropy: 4.4810 - val_loss: 1.2401 - val_sparse_categorical_crossentropy: 1.2401
# Epoch 2/100
# 22/22 [==============================] - 109s 5s/step - loss: 1.3046 - sparse_categorical_crossentropy: 1.3046 - val_loss: 1.2541 - val_sparse_categorical_crossentropy: 1.2541
# Epoch 3/100
# 22/22 [==============================] - 110s 5s/step - loss: 1.3104 - sparse_categorical_crossentropy: 1.3104 - val_loss: 1.1811 - val_sparse_categorical_crossentropy: 1.1811
# Epoch 4/100
# 22/22 [==============================] - 110s 5s/step - loss: 1.2595 - sparse_categorical_crossentropy: 1.2595 - val_loss: 1.1422 - val_sparse_categorical_crossentropy: 1.1422
# Epoch 5/100
# 22/22 [==============================] - 110s 5s/step - loss: 1.1479 - sparse_categorical_crossentropy: 1.1479 - val_loss: 1.0560 - val_sparse_categorical_crossentropy: 1.0560
# Epoch 6/100
# 22/22 [==============================] - 110s 5s/step - loss: 1.1187 - sparse_categorical_crossentropy: 1.1187 - val_loss: 1.1352 - val_sparse_categorical_crossentropy: 1.1352
# Epoch 7/100
# 22/22 [==============================] - 110s 5s/step - loss: 1.1232 - sparse_categorical_crossentropy: 1.1232 - val_loss: 0.9554 - val_sparse_categorical_crossentropy: 0.9554
# Epoch 8/100
# 22/22 [==============================] - 109s 5s/step - loss: 1.0006 - sparse_categorical_crossentropy: 1.0006 - val_loss: 1.1907 - val_sparse_categorical_crossentropy: 1.1907
# Epoch 9/100
# 22/22 [==============================] - 109s 5s/step - loss: 1.0828 - sparse_categorical_crossentropy: 1.0828 - val_loss: 1.5598 - val_sparse_categorical_crossentropy: 1.5598
# Epoch 10/100
# 22/22 [==============================] - 111s 5s/step - loss: 1.2266 - sparse_categorical_crossentropy: 1.2266 - val_loss: 1.1841 - val_sparse_categorical_crossentropy: 1.1841
# Epoch 11/100
# 22/22 [==============================] - 109s 5s/step - loss: 1.2087 - sparse_categorical_crossentropy: 1.2087 - val_loss: 1.1563 - val_sparse_categorical_crossentropy: 1.1563
# Epoch 12/100
# 22/22 [==============================] - 110s 5s/step - loss: 1.1628 - sparse_categorical_crossentropy: 1.1628 - val_loss: 1.1173 - val_sparse_categorical_crossentropy: 1.1173
# Epoch 13/100
# 22/22 [==============================] - 109s 5s/step - loss: 1.1816 - sparse_categorical_crossentropy: 1.1816 - val_loss: 1.0780 - val_sparse_categorical_crossentropy: 1.0780
# <tf.Variable 'Adam/learning_rate:0' shape=() dtype=float32, numpy=5e-05>
# Epoch 1/200
# 22/22 [==============================] - 452s 19s/step - loss: 0.7213 - accuracy: 0.7455 - val_loss: 0.2913 - val_accuracy: 0.8904
# Epoch 2/200
# 22/22 [==============================] - 445s 20s/step - loss: 0.1877 - accuracy: 0.9359 - val_loss: 0.3045 - val_accuracy: 0.9068
# Epoch 3/200
# 22/22 [==============================] - 469s 21s/step - loss: 0.1106 - accuracy: 0.9648 - val_loss: 0.3590 - val_accuracy: 0.8986
# Epoch 4/200
# 22/22 [==============================] - 428s 19s/step - loss: 0.0936 - accuracy: 0.9624 - val_loss: 0.2901 - val_accuracy: 0.9096
# Epoch 5/200
# 22/22 [==============================] - 429s 19s/step - loss: 0.0938 - accuracy: 0.9685 - val_loss: 0.3355 - val_accuracy: 0.9123
# Epoch 6/200
# 22/22 [==============================] - 429s 19s/step - loss: 0.0699 - accuracy: 0.9795 - val_loss: 0.3061 - val_accuracy: 0.9096
# Epoch 7/200
# 22/22 [==============================] - 428s 19s/step - loss: 0.0666 - accuracy: 0.9835 - val_loss: 0.2599 - val_accuracy: 0.9151
# Epoch 8/200
# 22/22 [==============================] - 429s 19s/step - loss: 0.0548 - accuracy: 0.9807 - val_loss: 0.2318 - val_accuracy: 0.9342
# Epoch 9/200
# 22/22 [==============================] - 431s 19s/step - loss: 0.0256 - accuracy: 0.9917 - val_loss: 0.2638 - val_accuracy: 0.9233
# Epoch 10/200
# 22/22 [==============================] - 428s 19s/step - loss: 0.0258 - accuracy: 0.9915 - val_loss: 0.2713 - val_accuracy: 0.9342
# Epoch 11/200
# 22/22 [==============================] - 428s 19s/step - loss: 0.0267 - accuracy: 0.9895 - val_loss: 0.2824 - val_accuracy: 0.9123
# Epoch 12/200
# 22/22 [==============================] - 429s 19s/step - loss: 0.0245 - accuracy: 0.9925 - val_loss: 0.2643 - val_accuracy: 0.9370
# Epoch 13/200
# 22/22 [==============================] - 429s 19s/step - loss: 0.0221 - accuracy: 0.9950 - val_loss: 0.2998 - val_accuracy: 0.9178
# Epoch 14/200
# 22/22 [==============================] - 429s 19s/step - loss: 0.0308 - accuracy: 0.9874 - val_loss: 0.3350 - val_accuracy: 0.9096
# Epoch 15/200
# 22/22 [==============================] - 429s 19s/step - loss: 0.0227 - accuracy: 0.9927 - val_loss: 0.3669 - val_accuracy: 0.9123
# Epoch 16/200
# 22/22 [==============================] - 429s 19s/step - loss: 0.0402 - accuracy: 0.9901 - val_loss: 0.2778 - val_accuracy: 0.9096
# Epoch 17/200
# 22/22 [==============================] - 429s 19s/step - loss: 0.0478 - accuracy: 0.9855 - val_loss: 0.2285 - val_accuracy: 0.9370
# Epoch 18/200
# 22/22 [==============================] - 430s 19s/step - loss: 0.0135 - accuracy: 0.9968 - val_loss: 0.2308 - val_accuracy: 0.9370
# Epoch 19/200
# 22/22 [==============================] - 428s 19s/step - loss: 0.0114 - accuracy: 0.9978 - val_loss: 0.2351 - val_accuracy: 0.9479
# Epoch 20/200
# 22/22 [==============================] - 428s 19s/step - loss: 0.0117 - accuracy: 0.9966 - val_loss: 0.2551 - val_accuracy: 0.9425
# Epoch 21/200
# 22/22 [==============================] - 428s 19s/step - loss: 0.0172 - accuracy: 0.9958 - val_loss: 0.2943 - val_accuracy: 0.9342
# Epoch 22/200
# 22/22 [==============================] - 428s 19s/step - loss: 0.0065 - accuracy: 0.9983 - val_loss: 0.2684 - val_accuracy: 0.9370
# Epoch 23/200
# 22/22 [==============================] - 428s 19s/step - loss: 0.0121 - accuracy: 0.9941 - val_loss: 0.2843 - val_accuracy: 0.9452
# Epoch 24/200
# 22/22 [==============================] - 428s 19s/step - loss: 0.0117 - accuracy: 0.9971 - val_loss: 0.3101 - val_accuracy: 0.9315
# Epoch 25/200
# 22/22 [==============================] - 429s 19s/step - loss: 0.0114 - accuracy: 0.9960 - val_loss: 0.2775 - val_accuracy: 0.9452
# Epoch 26/200
# 22/22 [==============================] - 430s 19s/step - loss: 0.0100 - accuracy: 0.9962 - val_loss: 0.2911 - val_accuracy: 0.9370
# Epoch 27/200
# 22/22 [==============================] - 429s 19s/step - loss: 0.0057 - accuracy: 0.9986 - val_loss: 0.2854 - val_accuracy: 0.9397
# Epoch 28/200
# 22/22 [==============================] - 429s 19s/step - loss: 0.0061 - accuracy: 0.9980 - val_loss: 0.2678 - val_accuracy: 0.9397
# Epoch 29/200
# 22/22 [==============================] - 429s 19s/step - loss: 0.0100 - accuracy: 0.9982 - val_loss: 0.2516 - val_accuracy: 0.9342
# INFO:tensorflow:Assets written to: models/EfficientNetB6/assets
# Epoch 1/2
# 22/22 [==============================] - 409s 18s/step - loss: 0.1854 - accuracy: 0.9572
# Epoch 2/2
# 22/22 [==============================] - 409s 18s/step - loss: 0.0776 - accuracy: 0.9789
# 100%|█████████████████████████████████████████| 105k/105k [00:00<00:00, 263kB/s]
# Successfully submitted to Plant Pathology 2020 - FGVC7fileName               date                 description                         status    publicScore  privateScore
# ---------------------  -------------------  ----------------------------------  --------  -----------  ------------
# EfficientNetB6.csv     2021-02-06 20:03:18  EfficientNetB6 baseline 2021-02-06  complete  0.94181      0.92909
# EfficientNetB5.csv     2021-02-06 15:51:55  EfficientNetB5 baseline 2021-02-06  complete  0.94710      0.93022
# EfficientNetB4.csv     2021-02-06 13:32:05  EfficientNetB4 baseline 2021-02-06  complete  0.93628      0.93089
# EfficientNetB3.csv     2021-02-06 11:32:30  EfficientNetB3 baseline 2021-02-06  complete  0.93135      0.91675
# EfficientNetB2.csv     2021-02-06 10:28:00  EfficientNetB2 baseline 2021-02-06  complete  0.92274      0.92275
# EfficientNetB1.csv     2021-02-06 09:28:56  EfficientNetB1 baseline 2021-02-06  complete  0.94027      0.93291
# EfficientNetB0.csv     2021-02-06 08:36:55  EfficientNetB0 baseline 2021-02-06  complete  0.93026      0.92324
# xception.csv           2021-02-06 07:19:59  xception baseline 20210130          complete  0.94455      0.91202
# xception.csv           2021-02-06 04:18:08  xception baseline 2021-02-06        complete  0.88840      0.87141
# NASNet.csv             2021-01-31 19:49:33  NAXNet baseline 20210131            complete  0.91386      0.90567
# xception.csv           2021-01-31 16:12:55  xception baseline 20210130          complete  0.88840      0.87141
# inceptionResNetv2.csv  2021-01-31 02:36:15  inception baseline 20210130         complete  0.92493      0.93380
